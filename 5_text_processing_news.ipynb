# %% [markdown]
# This notebook contains the code to load the "US economy news" dataset

# %%
import pandas as pd

# %%
df_news = pd.read_csv('US-Economic-News.csv', delimiter=',', encoding = 'ISO-8859-1')

# %%
df_news.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'positivity', 'positivity:confidence', 'relevance',
#        'relevance:confidence', 'articleid', 'date', 'headline',
#        'positivity_gold', 'relevance_gold', 'text'],
#       dtype='object')

# %%
df_news.head(20)
# Out:
#      _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0   842613455    False   finalized                   3     12/5/15 17:48
# 1   842613456    False   finalized                   3     12/5/15 16:54
# 2   842613457    False   finalized                   3      12/5/15 1:59
# 3   842613458    False   finalized                   3      12/5/15 2:19
# 4   842613459    False   finalized                   3     12/5/15 17:48
# 5   842613460    False   finalized                   3     12/4/15 23:15
# 6   842613461    False   finalized                   3      12/5/15 7:35
# 7   842613462    False   finalized                   3     12/5/15 17:22
# 8   842613463    False   finalized                   3     12/4/15 23:07
# 9   842613464    False   finalized                   3     12/5/15 18:40
# 10  842613465    False   finalized                   3     12/5/15 14:03
# 11  842613466    False   finalized                   3      12/5/15 6:09
# 12  842613467    False   finalized                   3      12/5/15 1:29
# 13  842613468    False   finalized                   3     12/5/15 13:49
# 14  842613469    False   finalized                   3      12/5/15 1:22
# 15  842613470    False   finalized                   3     12/5/15 13:45
# 16  842613471    False   finalized                   3     12/5/15 11:36
# 17  842613472    False   finalized                   3      12/5/15 0:15
# 18  842613473    False   finalized                   3      12/5/15 0:22
# 19  842613474    False   finalized                   3     12/5/15 11:27
#
#     positivity  positivity:confidence relevance  relevance:confidence  \
# 0          3.0                 0.6400       yes                0.6400
# 1          NaN                    NaN        no                1.0000
# 2          NaN                    NaN        no                1.0000
# 3          NaN                 0.0000        no                0.6750
# 4          3.0                 0.3257       yes                0.6400
# 5          3.0                 0.6783       yes                1.0000
# 6          NaN                 0.0000        no                0.6496
# 7          NaN                    NaN        no                1.0000
# 8          NaN                    NaN        no                1.0000
# 9          4.0                 0.6657       yes                1.0000
# 10         NaN                    NaN        no                1.0000
# 11         NaN                 0.0000        no                0.6491
# 12         4.0                 0.3388       yes                0.6777
# 13         NaN                    NaN        no                1.0000
# 14         NaN                 0.0000        no                0.6583
# 15         NaN                    NaN        no                1.0000
# 16         NaN                    NaN        no                1.0000
# 17         3.0                 0.6422       yes                1.0000
# 18         NaN                    NaN        no                1.0000
# 19         NaN                    NaN        no                1.0000
#
#          articleid      date  \
# 0    wsj_398217788   8/14/91
# 1    wsj_399019502   8/21/07
# 2    wsj_398284048  11/14/91
# 3    wsj_397959018   6/16/86
# 4    wsj_398838054   10/4/02
# 5    wsj_905654974  11/23/11
# 6    wsj_398739166   5/24/01
# 7    wsj_397957465  10/22/86
# 8    wsj_398737834   5/30/01
# 9    wsj_397912506   11/1/84
# 10   wsj_399004010   12/8/05
# 11   wsj_398714238   4/30/99
# 12   wsj_738300385    8/3/10
# 13   wsj_398096941   10/6/89
# 14   wsj_398558612    7/1/94
# 15  wsj_1125026709   11/1/12
# 16   wsj_398827026    3/3/00
# 17   wsj_398459353    2/2/95
# 18  wsj_1552366266    8/8/14
# 19   wsj_398807329  11/19/02
#
#                                              headline  positivity_gold  \
# 0               Yields on CDs Fell in the Latest Week              NaN
# 1   The Morning Brief: White House Seeks to Limit ...              NaN
# 2   Banking Bill Negotiators Set Compromise --- Pl...              NaN
# 3   Manager's Journal: Sniffing Out Drug Abusers I...              NaN
# 4   Currency Trading: Dollar Remains in Tight Rang...              NaN
# 5                Stocks Fall Again; BofA, Alcoa Slide              NaN
# 6   Bank of Montreal, Royal Bank Profits Rose in 2...              NaN
# 7                Battle Over Medical Costs Isn't Over              NaN
# 8     Sequenom to Buy Gemini Genomics In Stock Accord              NaN
# 9   U.S. Dollar Falls Against Most Currencies; Dec...              NaN
# 10     Dow Falls 45.95, Late GM Surge Stanches Losses              NaN
# 11             MCI Surpasses Expectations On Earnings              NaN
# 12               Defending Yourself Against Deflation              NaN
# 13  Lending to Firms Projected to Grow 9.2% Next Year              NaN
# 14  U.S., week ahead of economic summit, signals i...              NaN
# 15  Net Worth, Not Income, Is Right Measure of Ine...              NaN
# 16  The Americas: Ecuador Struggles Toward a Dolla...              NaN
# 17  Dollar Declines as Players Take Profits From R...              NaN
# 18  In Europe, Job Protections for Older Generatio...              NaN
# 19  Outlook for Business Investment Improves, but ...              NaN
#
#     relevance_gold                                               text
# 0              NaN  NEW YORK -- Yields on most certificates of dep...
# 1              NaN  The Wall Street Journal Online</br></br>The Mo...
# 2              NaN  WASHINGTON -- In an effort to achieve banking ...
# 3              NaN  The statistics on the enormous costs of employ...
# 4              NaN  NEW YORK -- Indecision marked the dollar's ton...
# 5              NaN  Stocks declined, as investors weighed slower-t...
# 6              NaN  TORONTO -- Royal Bank of Canada and Bank of Mo...
# 7              NaN  Many people think that the monster of health-c...
# 8              NaN  Sequenom Inc., a genomics-based biotechnology ...
# 9              NaN  The U.S. dollar declined against most major fo...
# 10             NaN  The Wall Street Journal Online</br></br>A LATE...
# 11             NaN  MCI WorldCom Inc., fueled by growth in Interne...
# 12             NaN  Author: James B. Stewart</br></br>The dreaded ...
# 13             NaN  NEW YORK -- Commercial and industrial loan vol...
# 14             NaN  WASHINGTON -- A week before an international e...
# 15             NaN  According to Kevin A. Hassett and Aparna Mathu...
# 16             NaN  OTAVALO, Ecuador -- The long black braid, the ...
# 17             NaN  NEW YORK -- The dollar sagged yesterday, as ne...
# 18             NaN  By the time the parents of Serena Violano were...
# 19             NaN  The outlook for business investment appears to...

# %%
# let's see how many news we have per relevance class
df_news.groupby(['relevance'])['articleid'].count()
# Out:
# relevance
# no          6571
# not sure       9
# yes         1420
# Name: articleid, dtype: int64

# %%
df_news['_trusted_judgments'].unique()
# Out:
# array([3])

# %%
len(df_news[df_news['positivity'].isna()])
# Out:
# 6580

# %%
len(df_news)
# Out:
# 8000
